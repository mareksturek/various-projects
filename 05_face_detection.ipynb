# %% [markdown]
# ## Face Detection
#
# 10/23/2020

# %% [markdown]
# ---

# %%
# Import libraries

import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# Import picture, convert to gray


os.chdir('//Users/mareksturek/Documents/GitHub/various-projects/data')
img = cv2.imread('brooke-cagle-g1Kr4Ozfoac-unsplash.jpg') 
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap = 'gray')
plt.imshow(img)

# %%
# Pre-defined classifier to identify faces
# Haar cascade classifier employs a machine learning approach for visual object detection

haar_cascade_face = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
# detectMultiscale module of the classifier. 
# This function will return a rectangle with coordinates(x,y,w,h) around the detected face. 

faces_rects = haar_cascade_face.detectMultiScale(gray, scaleFactor = 1.2, minNeighbors = 5)

# %%
# How many faces present?

print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  2

# %%
# Drawing rectangle

for (x,y,w,h) in faces_rects:
     cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
# Convert image to RGB

def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB) ## convert image to RGB

# %%
# Show image

plt.imshow(convertToRGB(img))
