# %% [markdown]
# ## Active Volcano
#
# 10/23/2020

# %% [markdown]
# ---

# %%
# Import libraries

import os
import numpy as np
import pandas as pd
import folium as fo
# %matplotlib inline

# %%
# My homeland

map = fo.Map()
x = fo.FeatureGroup(name='Map of World')
x.add_child(fo.Marker(location=[48.6690,19.6990] , popup='Slovakia' , icon=fo.Icon(color='blue')))
map.add_child(x)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Active volcano

# Import dataset
os.chdir('//Users/mareksturek/Documents/GitHub/various-projects/data')
dataset = pd.read_csv('volcano.csv')

# %%
# Show on map in red

lat_vo = list(dataset['Latitude'])
lon_vo = list(dataset['Longitude'])
name_vo = list(dataset['Name'])

vol = fo.FeatureGroup(name='Map of World')

for lat,lon,name in zip(lat_vo,lon_vo,name_vo):
    vol.add_child(fo.Marker(location=[lat,lon] ,
                          popup=name , icon=fo.Icon(color='red')))
    
map.add_child(vol)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
